# %% [markdown]
# <a href="https://colab.research.google.com/github/EkaterinaElagina/Python-training-projects/blob/main/%D0%9A%D1%80%D0%B5%D0%B4%D0%B8%D1%82%D0%BD%D0%B0%D1%8F_%D0%B8%D1%81%D1%82%D0%BE%D1%80%D0%B8%D1%8F_%D0%BA%D0%BB%D0%B8%D0%B5%D0%BD%D1%82%D0%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt 
import numpy as np 
import seaborn as sns 
import pandas as pd

# %%
df = pd.read_csv('C:/Users/User/Desktop/data.csv')

# %%
df
# Out:
#        order_id  cred_sum_cc_all  mfo_inqs_count_month  \
# 0       5498546              0.0                     0
# 1       5498604           1500.0                     0
# 2       5498609              0.1                     0
# 3       5498645           5000.0                     0
# 4       5498647              0.0                     0
# ...         ...              ...                   ...
# 23111   6697173              0.0                     0
# 23112   6697212              0.0                     1
# 23113   6697215           1000.0                     0
# 23114   6697264              0.0                     3
# 23115   6697265              0.0                     0
#
#        all_closed_creds_sum_all  bank_inqs_count_quarter  \
# 0                         40364                        0
# 1                         23456                        0
# 2                         17999                        3
# 3                        313247                        0
# ...

# %% [markdown]
# Количество клиентов, отправляющих запросы в другие МФО, составляет менее половины всех обращающихся клиентов

# %%
df[df['mfo_inqs_count_month'] > 0]
# Out:
#        order_id  cred_sum_cc_all  mfo_inqs_count_month  \
# 7       5499337         158000.0                     6
# 8       5499365          50000.0                     2
# 9       5499397          44000.0                     1
# 10      5499407              0.0                     1
# 11      5499444          48000.0                     6
# ...         ...              ...                   ...
# 23102   6696870              0.0                     2
# 23105   6696941           3000.0                     3
# 23108   6697060           8000.0                     3
# 23112   6697212              0.0                     1
# 23114   6697264              0.0                     3
#
#        all_closed_creds_sum_all  bank_inqs_count_quarter  \
# 7                        845853                        0
# 8                         58500                       14
# 9                        367842                        3
# 10                        44500                        0
# ...

# %%
Количество людей, повторно обращающися за кредитом почти вчетверо больше тех, кто обращается вперые

# %%
df[df['all_closed_creds_sum_all'] > 0]
# Out:
#        order_id  cred_sum_cc_all  mfo_inqs_count_month  \
# 0       5498546              0.0                     0
# 1       5498604           1500.0                     0
# 2       5498609              0.1                     0
# 3       5498645           5000.0                     0
# 5       5498726          31000.1                     0
# ...         ...              ...                   ...
# 23109   6697087              0.0                     0
# 23112   6697212              0.0                     1
# 23113   6697215           1000.0                     0
# 23114   6697264              0.0                     3
# 23115   6697265              0.0                     0
#
#        all_closed_creds_sum_all  bank_inqs_count_quarter  \
# 0                         40364                        0
# 1                         23456                        0
# 2                         17999                        3
# 3                        313247                        0
# ...

# %%
Количество запросов на кредиты в банке больше одного более чем у 16 тыс клиентов
Максимальное количество запросов на кредит - 67

# %%
df[df['bank_inqs_count_quarter'] > 0]
# Out:
#        order_id  cred_sum_cc_all  mfo_inqs_count_month  \
# 2       5498609              0.1                     0
# 4       5498647              0.0                     0
# 5       5498726          31000.1                     0
# 8       5499365          50000.0                     2
# 9       5499397          44000.0                     1
# ...         ...              ...                   ...
# 23110   6697091              0.0                     0
# 23111   6697173              0.0                     0
# 23112   6697212              0.0                     1
# 23113   6697215           1000.0                     0
# 23115   6697265              0.0                     0
#
#        all_closed_creds_sum_all  bank_inqs_count_quarter  \
# 2                         17999                        3
# 4                             0                        1
# 5                          9800                        3
# 8                         58500                       14
# ...

# %%
df['bank_inqs_count_quarter'].max()
# Out:
# 67

# %% [markdown]
# 8042 клиента имели 1 и более просрочку по кредиту за год, почти все из должников не платят более полугода
# Максимальная просрочка по кредиту составляет 1914581.16 руб

# %%
df[df['cred_max_overdue_max_ly']>0]
# Out:
#        order_id  cred_sum_cc_all  mfo_inqs_count_month  \
# 5       5498726         31000.10                     0
# 7       5499337        158000.00                     6
# 9       5499397         44000.00                     1
# 14      5499574          5000.00                     2
# 16      5499689        160897.58                     1
# ...         ...              ...                   ...
# 23096   6696650             0.00                     0
# 23099   6696789        117000.00                     0
# 23109   6697087             0.00                     0
# 23112   6697212             0.00                     1
# 23114   6697264             0.00                     3
#
#        all_closed_creds_sum_all  bank_inqs_count_quarter  \
# 5                          9800                        3
# 7                        845853                        0
# 9                        367842                        3
# 14                        33920                        4
# ...

# %%
df[df['cred_max_overdue_max_ly']>5]
# Out:
#        order_id  cred_sum_cc_all  mfo_inqs_count_month  \
# 5       5498726         31000.10                     0
# 7       5499337        158000.00                     6
# 9       5499397         44000.00                     1
# 14      5499574          5000.00                     2
# 16      5499689        160897.58                     1
# ...         ...              ...                   ...
# 23096   6696650             0.00                     0
# 23099   6696789        117000.00                     0
# 23109   6697087             0.00                     0
# 23112   6697212             0.00                     1
# 23114   6697264             0.00                     3
#
#        all_closed_creds_sum_all  bank_inqs_count_quarter  \
# 5                          9800                        3
# 7                        845853                        0
# 9                        367842                        3
# 14                        33920                        4
# ...

# %%
df['cred_max_overdue_max_ly'].max()
# Out:
# 1914581.16

# %% [markdown]
# Основная часть клиентов имеет активные кредиты на сумму, не превышающую 100 000р

# %%
df[df['all_active_creds_sum_all'] > 100000]
# Out:
#        order_id  cred_sum_cc_all  mfo_inqs_count_month  \
# 5       5498726          31000.1                     0
# 12      5499448          81550.0                    11
# 17      5499715          45001.0                     0
# 19      5499827         114000.0                     0
# 20      5499828         160000.0                     1
# ...         ...              ...                   ...
# 23087   6696226          10000.1                     0
# 23089   6696339          50000.0                     0
# 23098   6696767              0.0                     0
# 23099   6696789         117000.0                     0
# 23115   6697265              0.0                     0
#
#        all_closed_creds_sum_all  bank_inqs_count_quarter  \
# 5                          9800                        3
# 12                       231604                        5
# 17                       107584                        0
# 19                       439223                        4
# ...

# %% [markdown]
# Большинство клиентов, столкнувшихся с просрочкой, имеют текущие кредиты на сумму от 10 000 до 100 000 р

# %%
df.query ("cred_max_overdue_max_ly > 5 & all_active_creds_sum_all > 10000")
# Out:
#        order_id  cred_sum_cc_all  mfo_inqs_count_month  \
# 5       5498726          31000.1                     0
# 7       5499337         158000.0                     6
# 9       5499397          44000.0                     1
# 17      5499715          45001.0                     0
# 20      5499828         160000.0                     1
# ...         ...              ...                   ...
# 23087   6696226          10000.1                     0
# 23099   6696789         117000.0                     0
# 23109   6697087              0.0                     0
# 23112   6697212              0.0                     1
# 23114   6697264              0.0                     3
#
#        all_closed_creds_sum_all  bank_inqs_count_quarter  \
# 5                          9800                        3
# 7                        845853                        0
# 9                        367842                        3
# 17                       107584                        0
# ...

# %% [markdown]
# Сумма закрытых кредитов в этом году 695086289 р

# %%
df['all_closed_creds_sum_ly'].sum()
# Out:
# 695086289

# %% [markdown]
# Средняя сумма МФО кредитов, выданных за последние 3 месяца составила 97747565.62618527 р

# %%
df['mfo_cred_mean_sum_3lm'].sum()
# Out:
# 97747565.62618527

# %% [markdown]
# Количество просрочек более 90 дней - 23116

# %%
df['mfo_cred_mean_sum_3lm'].count()
# Out:
# 23116

# %% [markdown]
# Cумма просрочек по кредитным картам составляет 112763828.1 руб

# %%
df[['delay_more_sum_all', 'cred_sum_cc_all', 'mfo_inqs_count_month']].corr()
# Out:
#                       delay_more_sum_all  cred_sum_cc_all  \
# delay_more_sum_all              1.000000         0.140823
# cred_sum_cc_all                 0.140823         1.000000
# mfo_inqs_count_month           -0.049465         0.058677
#
#                       mfo_inqs_count_month
# delay_more_sum_all               -0.049465
# cred_sum_cc_all                   0.058677
# mfo_inqs_count_month              1.000000

# %% [markdown]
# Количество уникальных регионов, в которых брали кредит - 90
# Максимальное количество кредитов (23116) выдано в 99 регионе на сумму 1101066 руб

# %%
df[['cred_sum_overdue_cc_all']].sum()
# Out:
# cred_sum_overdue_cc_all    112763828.1
# dtype: float64

# %%
df['region'].nunique()
# Out:
# 90

# %%
df['region'].max()
# Out:
# 99

# %%
df['region'].count()
# Out:
# 23116

# %%
df['region'].sum()
# Out:
# 1101066

# %% [markdown]
# На гистограмме видно, что больше всего кредитов берут представители рабочих професиий.
# 5 - рабочие профессии (слесарь, токарь). 3 - офисный работник (бухгалтер, программист). 1 - госслужащий (полицейский, медсестра)

# %%
df['work_code'].value_counts()
# Out:
# 5    7747
# 2    4881
# 3    4834
# 4    3570
# 1    2084
# Name: work_code, dtype: int64

# %%
labels = ["5", "2", "3", "4", "1"]
plt.pie(df['work_code'].value_counts(), labels = labels)
plt.show()

# %%
plt.hist(df['month_income'])
plt.show()
